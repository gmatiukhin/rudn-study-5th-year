# %% [markdown]
# ### РОССИЙСКИЙ УНИВЕРСИТЕТ ДРУЖБЫ НАРОДОВ
#
# #### Факультет физико-математических и естественных наук
# #### Кафедра математического моделирования и искусственного интеллекта
#
#
# ## ОТЧЕТ ПО ТЕМЕ № 1, задание № 1
#
# ### Дисциплина: Глубокое обучение
#
#
#
# ##### Студент:  Матюхин Григорий Васильевич
# ##### Группа:   НПИмд-01-25

# %%
import keras
import keras_cv
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1758917164.292282  358871 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1758917164.292298  358871 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1758917164.292300  358871 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1758917164.292301  358871 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-09-26 23:06:04.295461: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %%
import tensorflow as tf
tf.config.list_logical_devices("GPU")
# Out:
# I0000 00:00:1758917166.133642  358871 gpu_device.cc:2395] Ignoring visible gpu device (device: 1, name: AMD Radeon Graphics, pci bus id: 0000:11:00.0) with AMDGPU version : gfx1036. The supported AMDGPU versions are gfx900, gfx906, gfx908, gfx90a, gfx942, gfx950, gfx1030, gfx1100, gfx1101, gfx1102, gfx1200, gfx1201.
# I0000 00:00:1758917166.208141  358871 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15030 MB memory:  -> device: 0, name: AMD Radeon RX 9070 XT, pci bus id: 0000:03:00.0
# [LogicalDevice(name='/device:GPU:0', device_type='GPU')]

# %%
stable_diffusion = keras_cv.models.StableDiffusion(img_height=256, img_width=256)
# Out:
# By using this model checkpoint, you acknowledge that its usage is subject to the terms of the CreativeML Open RAIL-M license at https://raw.githubusercontent.com/CompVis/stable-diffusion/main/LICENSE

# %%
images = stable_diffusion.generate_image(stable_diffusion.encode_text("cancer, crab, astrology, sign"), batch_size=2)

from matplotlib import pyplot as plt
for image in images:
    plt.imshow(image)
    plt.show()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1758917169.002784  359160 service.cc:152] XLA service 0x7f9d0c004b00 initialized for platform ROCM (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1758917169.002800  359160 service.cc:160]   StreamExecutor device (0): AMD Radeon RX 9070 XT, AMDGPU ISA version: gfx1201
# 2025-09-26 23:06:09.053780: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1758917172.482205  359160 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 43s 306ms/step
